# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)

import numpy as np
import matplotlib.pyplot as plt

import os
import PIL
import PIL.Image as Image

seed_choice = 42
tf.keras.utils.set_random_seed(
    seed_choice
)
# Out:
# 2.12.0

# %%
#!pip install git+https://github.com/tensorflow/docs

import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from  IPython import display


import pathlib
import shutil
import tempfile

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Drive already mounted at gdrive; to attempt to forcibly remount, call drive.mount("gdrive", force_remount=True).

# %%
archive = 'gdrive/MyDrive/Datasets/plants'
data_dir = pathlib.Path(archive).with_suffix('')

# %%
data_dir
# Out:
# PosixPath('gdrive/MyDrive/Datasets/plants')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 288

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.35,
  subset="training",
  seed=seed_choice,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 288 files belonging to 2 classes.
# Using 188 files for training.

# %%
STEPS_PER_EPOCH = len(train_ds)

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.35,
  subset="validation",
  seed=seed_choice,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 288 files belonging to 2 classes.
# Using 100 files for validation.

# %%
validate_ds =  val_ds

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['healthy', 'wilted']

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
  return [
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.metrics.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=1)
  return history

# %%
INPUT_SHAPE = (None, 180, 180, 3)

# %%
tiny_model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1)])

tiny_model.build(INPUT_SHAPE)

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  flatten (Flatten)           (None, 1013888)           0
#
#  dense (Dense)               (None, 1)                 1013889
#
# =================================================================
# Total params: 1,014,785
# Trainable params: 1,014,785
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 13s 293ms/step - loss: 2.9144 - binary_crossentropy: 2.9144 - accuracy: 0.5426 - val_loss: 2.2710 - val_binary_crossentropy: 2.2710 - val_accuracy: 0.4700
# Epoch 2/10
# 6/6 [==============================] - 3s 220ms/step - loss: 0.8189 - binary_crossentropy: 0.8189 - accuracy: 0.6755 - val_loss: 1.0205 - val_binary_crossentropy: 1.0205 - val_accuracy: 0.5600
# Epoch 3/10
# 6/6 [==============================] - 4s 223ms/step - loss: 0.3234 - binary_crossentropy: 0.3234 - accuracy: 0.8457 - val_loss: 0.7313 - val_binary_crossentropy: 0.7313 - val_accuracy: 0.6600
# Epoch 4/10
# 6/6 [==============================] - 3s 218ms/step - loss: 0.1692 - binary_crossentropy: 0.1692 - accuracy: 0.9574 - val_loss: 0.6410 - val_binary_crossentropy: 0.6410 - val_accuracy: 0.5500
# Epoch 5/10
# 6/6 [==============================] - 5s 533ms/step - loss: 0.0713 - binary_crossentropy: 0.0713 - accuracy: 0.9840 - val_loss: 0.7386 - val_binary_crossentropy: 0.7386 - val_accuracy: 0.6600
# Epoch 6/10
# 6/6 [==============================] - 5s 355ms/step - loss: 0.0272 - binary_crossentropy: 0.0272 - accuracy: 0.9947 - val_loss: 0.7431 - val_binary_crossentropy: 0.7431 - val_accuracy: 0.6400
# Epoch 7/10
# 6/6 [==============================] - 5s 219ms/step - loss: 0.0244 - binary_crossentropy: 0.0244 - accuracy: 0.9947 - val_loss: 0.7767 - val_binary_crossentropy: 0.7767 - val_accuracy: 0.6500
# Epoch 8/10
# 6/6 [==============================] - 3s 214ms/step - loss: 0.0122 - binary_crossentropy: 0.0122 - accuracy: 0.9947 - val_loss: 0.7891 - val_binary_crossentropy: 0.7891 - val_accuracy: 0.6900
# Epoch 9/10
# 6/6 [==============================] - 3s 212ms/step - loss: 0.0051 - binary_crossentropy: 0.0051 - accuracy: 1.0000 - val_loss: 0.8530 - val_binary_crossentropy: 0.8530 - val_accuracy: 0.6900
# Epoch 10/10
# 6/6 [==============================] - 4s 216ms/step - loss: 0.0026 - binary_crossentropy: 0.0026 - accuracy: 1.0000 - val_loss: 0.8866 - val_binary_crossentropy: 0.8866 - val_accuracy: 0.6700

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
#plt.ylim([0.5, 0.7])

# %%
num_classes = 1

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %%
model.build(INPUT_SHAPE)

# %%
size_histories['ConvPool'] = compile_and_fit(model, 'sizes/ConvPool')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_1 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 41, 41, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dense_1 (Dense)             (None, 128)               1638528
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,658,049
# Trainable params: 1,658,049
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 7s 323ms/step - loss: 0.7829 - binary_crossentropy: 0.7829 - accuracy: 0.5213 - val_loss: 0.6863 - val_binary_crossentropy: 0.6863 - val_accuracy: 0.5200
# Epoch 2/10
# 6/6 [==============================] - 5s 234ms/step - loss: 0.6886 - binary_crossentropy: 0.6886 - accuracy: 0.4947 - val_loss: 0.6756 - val_binary_crossentropy: 0.6756 - val_accuracy: 0.5200
# Epoch 3/10
# 6/6 [==============================] - 3s 222ms/step - loss: 0.6378 - binary_crossentropy: 0.6378 - accuracy: 0.5904 - val_loss: 0.6334 - val_binary_crossentropy: 0.6334 - val_accuracy: 0.5700
# Epoch 4/10
# 6/6 [==============================] - 3s 225ms/step - loss: 0.5699 - binary_crossentropy: 0.5699 - accuracy: 0.6489 - val_loss: 0.6680 - val_binary_crossentropy: 0.6680 - val_accuracy: 0.6600
# Epoch 5/10
# 6/6 [==============================] - 5s 308ms/step - loss: 0.5068 - binary_crossentropy: 0.5068 - accuracy: 0.7021 - val_loss: 0.6648 - val_binary_crossentropy: 0.6648 - val_accuracy: 0.6500
# Epoch 6/10
# 6/6 [==============================] - 4s 286ms/step - loss: 0.4768 - binary_crossentropy: 0.4768 - accuracy: 0.7553 - val_loss: 0.6182 - val_binary_crossentropy: 0.6182 - val_accuracy: 0.6200
# Epoch 7/10
# 6/6 [==============================] - 3s 224ms/step - loss: 0.4300 - binary_crossentropy: 0.4300 - accuracy: 0.7926 - val_loss: 0.6605 - val_binary_crossentropy: 0.6605 - val_accuracy: 0.6400
# Epoch 8/10
# 6/6 [==============================] - 6s 548ms/step - loss: 0.3687 - binary_crossentropy: 0.3687 - accuracy: 0.7872 - val_loss: 0.6631 - val_binary_crossentropy: 0.6631 - val_accuracy: 0.6800
# Epoch 9/10
# 6/6 [==============================] - 3s 219ms/step - loss: 0.3088 - binary_crossentropy: 0.3088 - accuracy: 0.8245 - val_loss: 0.7980 - val_binary_crossentropy: 0.7980 - val_accuracy: 0.6800
# Epoch 10/10
# 6/6 [==============================] - 4s 289ms/step - loss: 0.3015 - binary_crossentropy: 0.3015 - accuracy: 0.8564 - val_loss: 0.8100 - val_binary_crossentropy: 0.8100 - val_accuracy: 0.6600

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.0, 1.0])
# Out:
# (0.0, 1.0)

# %%
model2 = tf.keras.models.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(num_classes)
])

model2.build(INPUT_SHAPE)

# %%
size_histories['Dropout'] = compile_and_fit(model2, 'sizes/Dropout')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  flatten_2 (Flatten)         (None, 97200)             0
#
#  dense_3 (Dense)             (None, 128)               12441728
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 12,441,857
# Trainable params: 12,441,857
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 6s 339ms/step - loss: 21.6772 - binary_crossentropy: 21.6772 - accuracy: 0.4840 - val_loss: 2.9286 - val_binary_crossentropy: 2.9286 - val_accuracy: 0.6000
# Epoch 2/10
# 6/6 [==============================] - 3s 212ms/step - loss: 5.9730 - binary_crossentropy: 5.9730 - accuracy: 0.6330 - val_loss: 3.3312 - val_binary_crossentropy: 3.3312 - val_accuracy: 0.5900
# Epoch 3/10
# 6/6 [==============================] - 3s 209ms/step - loss: 3.5458 - binary_crossentropy: 3.5458 - accuracy: 0.6755 - val_loss: 3.1698 - val_binary_crossentropy: 3.1698 - val_accuracy: 0.5200
# Epoch 4/10
# 6/6 [==============================] - 4s 210ms/step - loss: 3.0749 - binary_crossentropy: 3.0749 - accuracy: 0.6277 - val_loss: 6.3281 - val_binary_crossentropy: 6.3281 - val_accuracy: 0.4800
# Epoch 5/10
# 6/6 [==============================] - 3s 210ms/step - loss: 3.4163 - binary_crossentropy: 3.4163 - accuracy: 0.5745 - val_loss: 1.2106 - val_binary_crossentropy: 1.2106 - val_accuracy: 0.6200
# Epoch 6/10
# 6/6 [==============================] - 3s 202ms/step - loss: 1.6363 - binary_crossentropy: 1.6363 - accuracy: 0.6809 - val_loss: 2.2046 - val_binary_crossentropy: 2.2046 - val_accuracy: 0.5700
# Epoch 7/10
# 6/6 [==============================] - 5s 528ms/step - loss: 0.9288 - binary_crossentropy: 0.9288 - accuracy: 0.6489 - val_loss: 0.8141 - val_binary_crossentropy: 0.8141 - val_accuracy: 0.6500
# Epoch 8/10
# 6/6 [==============================] - 4s 268ms/step - loss: 0.5736 - binary_crossentropy: 0.5736 - accuracy: 0.7287 - val_loss: 0.8612 - val_binary_crossentropy: 0.8612 - val_accuracy: 0.5900
# Epoch 9/10
# 6/6 [==============================] - 4s 268ms/step - loss: 0.4935 - binary_crossentropy: 0.4935 - accuracy: 0.7394 - val_loss: 0.7548 - val_binary_crossentropy: 0.7548 - val_accuracy: 0.5800
# Epoch 10/10
# 6/6 [==============================] - 3s 244ms/step - loss: 0.4558 - binary_crossentropy: 0.4558 - accuracy: 0.7394 - val_loss: 0.7118 - val_binary_crossentropy: 0.7118 - val_accuracy: 0.6100

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.0, 1.0])
# Out:
# (0.0, 1.0)

# %%
model3 = tf.keras.models.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(num_classes)
])

model3.build(INPUT_SHAPE)

size_histories['ConvPoolDropout'] = compile_and_fit(model3, 'sizes/ConvPoolDropout')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 41, 41, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 20, 20, 32)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_5 (Dense)             (None, 128)               1638528
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,658,049
# Trainable params: 1,658,049
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 6s 253ms/step - loss: 0.8567 - binary_crossentropy: 0.8567 - accuracy: 0.4468 - val_loss: 0.6975 - val_binary_crossentropy: 0.6975 - val_accuracy: 0.5200
# Epoch 2/10
# 6/6 [==============================] - 3s 220ms/step - loss: 0.6868 - binary_crossentropy: 0.6868 - accuracy: 0.4947 - val_loss: 0.6879 - val_binary_crossentropy: 0.6879 - val_accuracy: 0.5200
# Epoch 3/10
# 6/6 [==============================] - 4s 288ms/step - loss: 0.6515 - binary_crossentropy: 0.6515 - accuracy: 0.5160 - val_loss: 0.6428 - val_binary_crossentropy: 0.6428 - val_accuracy: 0.5500
# Epoch 4/10
# 6/6 [==============================] - 5s 218ms/step - loss: 0.6002 - binary_crossentropy: 0.6002 - accuracy: 0.6330 - val_loss: 0.6211 - val_binary_crossentropy: 0.6211 - val_accuracy: 0.6000
# Epoch 5/10
# 6/6 [==============================] - 4s 287ms/step - loss: 0.5042 - binary_crossentropy: 0.5042 - accuracy: 0.7500 - val_loss: 0.7227 - val_binary_crossentropy: 0.7227 - val_accuracy: 0.5900
# Epoch 6/10
# 6/6 [==============================] - 3s 217ms/step - loss: 0.5167 - binary_crossentropy: 0.5167 - accuracy: 0.7074 - val_loss: 0.7054 - val_binary_crossentropy: 0.7054 - val_accuracy: 0.5800
# Epoch 7/10
# 6/6 [==============================] - 4s 224ms/step - loss: 0.4423 - binary_crossentropy: 0.4423 - accuracy: 0.7606 - val_loss: 0.7382 - val_binary_crossentropy: 0.7382 - val_accuracy: 0.6800
# Epoch 8/10
# 6/6 [==============================] - 3s 234ms/step - loss: 0.4120 - binary_crossentropy: 0.4120 - accuracy: 0.7660 - val_loss: 0.6807 - val_binary_crossentropy: 0.6807 - val_accuracy: 0.6300
# Epoch 9/10
# 6/6 [==============================] - 5s 544ms/step - loss: 0.3091 - binary_crossentropy: 0.3091 - accuracy: 0.8564 - val_loss: 0.6623 - val_binary_crossentropy: 0.6623 - val_accuracy: 0.6400
# Epoch 10/10
# 6/6 [==============================] - 4s 233ms/step - loss: 0.2314 - binary_crossentropy: 0.2314 - accuracy: 0.9096 - val_loss: 0.7810 - val_binary_crossentropy: 0.7810 - val_accuracy: 0.6500

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.0, 1.0])
# Out:
# (0.0, 1.0)
